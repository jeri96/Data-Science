# %% [markdown]
# # 🛍️SUPERMARKET SALES EXPLORATORY DATA ANALYSIS(EDA)🛍️

# %% [markdown]
# ### Introduction

# %% [markdown]
# The growth of supermarket in the most populated cities are increasing. The project aims to analyze supermarket sales across different branches and provide insight to understand the customer better. The dataset was taken from [Kaggle](https://www.kaggle.com/aungpyaeap/supermarket-sales). The dataset consists of a thousand rows and 17 columns.

# %% [markdown]
# #### Install the libraries

# %%
# !pip install jovian opendatasets numpy pandas missingno folium matplotlib seaborn  --upgrade --quiet

# %% [markdown]
# #### Dowload the dataset

# %%
# !pip install jovian opendatasets --upgrade --quiet #B0E0E6 #003699

# %%
dataset_url='https://www.kaggle.com/aungpyaeap/supermarket-sales'

# %%
import opendatasets as od
od.download(dataset_url)
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username:
#   jerielwadjas
# Your Kaggle Key:
#   ································
# Downloading supermarket-sales.zip to .\supermarket-sales
# 100%|██████████████████████████████████████████████████████████████████████████████| 35.9k/35.9k [00:00<00:00, 252kB/s]

# %%
#Import the libraries 

#Manipulate file
import os

# Numerical/Dataframe libraries
import pandas as pd 
import numpy as np

# Vizualizing NaN values
import missingno as msno

#Geolocalisation
import folium

#Vizualization
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# <h3 style="color: #B0E0E6; background-color: #7C99BD;">
#     READING THE DATASET
# <br>
# </h3>

# %%
#Rename file
# os.listdir('./supermarket-sales')
# os.rename('./supermarket-sales/supermarket_sales - Sheet1.csv','./supermarket-sales/supermarket.csv')

# %%
#Check if the file is in the folder
os.listdir('./supermarket-sales')
# Out:
# ['.ipynb_checkpoints', 'supermarket.csv']

# %%
path= './supermarket-sales/supermarket.csv'

# %%
#Read the dataset
supermarket_df= pd.read_csv(path)

# %%
supermarket_df.head(10).style.background_gradient(cmap='GnBu')
# Out:
# <style type="text/css">
# #T_415cb_row0_col6 {
#   background-color: #1272b1;
#   color: #f1f1f1;
# }
# #T_415cb_row0_col7, #T_415cb_row2_col7, #T_415cb_row4_col7, #T_415cb_row5_col7 {
#   background-color: #4db2d3;
#   color: #f1f1f1;
# }
# #T_415cb_row0_col8, #T_415cb_row0_col9, #T_415cb_row0_col13, #T_415cb_row0_col15 {
#   background-color: #3fa2ca;
#   color: #f1f1f1;
# }
# #T_415cb_row0_col14, #T_415cb_row1_col6, #T_415cb_row1_col14, #T_415cb_row2_col14, #T_415cb_row3_col14, #T_415cb_row4_col14, #T_415cb_row5_col14, #T_415cb_row5_col16, #T_415cb_row6_col14, #T_415cb_row7_col14, #T_415cb_row8_col7, #T_415cb_row8_col8, #T_415cb_row8_col9, #T_415cb_row8_col13, #T_415cb_row8_col14, #T_415cb_row8_col15, #T_415cb_row9_col14 {
#   background-color: #f7fcf0;
#   color: #000000;
# }
# #T_415cb_row0_col16 {
#   background-color: #085da0;
#   color: #f1f1f1;
# }
# #T_415cb_row1_col7 {
#   background-color: #a7ddb5;
#   color: #000000;
# }
# #T_415cb_row1_col8, #T_415cb_row1_col9, #T_415cb_row1_col13, #T_415cb_row1_col15 {
#   background-color: #f6fcef;
#   color: #000000;
# }
# #T_415cb_row1_col16, #T_415cb_row4_col6, #T_415cb_row7_col7, #T_415cb_row7_col8, #T_415cb_row7_col9, #T_415cb_row7_col13, #T_415cb_row7_col15 {
#   background-color: #084081;
#   color: #f1f1f1;
# }
# #T_415cb_row2_col6 {
#   background-color: #92d5bc;
#   color: #000000;
# }
# #T_415cb_row2_col8, #T_415cb_row2_col9, #T_415cb_row2_col13, #T_415cb_row2_col15 {
#   background-color: #a6dcb6;
#   color: #000000;
# }
# #T_415cb_row2_col16 {
#   background-color: #57b8d0;
#   color: #000000;
# }
# #T_415cb_row3_col6 {
#   background-color: #56b7d0;
#   color: #f1f1f1;
# }
# #T_415cb_row3_col7 {
#   background-color: #2a8bbe;
#   color: #f1f1f1;
# }
# #T_415cb_row3_col8, #T_415cb_row3_col9, #T_415cb_row3_col13, #T_415cb_row3_col15 {
#   background-color: #5abacf;
#   color: #000000;
# }
# #T_415cb_row3_col16 {
#   background-color: #2182b9;
#   color: #f1f1f1;
# }
# #T_415cb_row4_col8, #T_415cb_row4_col9, #T_415cb_row4_col13, #T_415cb_row4_col15 {
#   background-color: #1c7cb6;
#   color: #f1f1f1;
# }
# #T_415cb_row4_col16 {
#   background-color: #d1edcb;
#   color: #000000;
# }
# #T_415cb_row5_col6 {
#   background-color: #084485;
#   color: #f1f1f1;
# }
# #T_415cb_row5_col8, #T_415cb_row5_col9, #T_415cb_row5_col13, #T_415cb_row5_col15 {
#   background-color: #1f80b8;
#   color: #f1f1f1;
# }
# #T_415cb_row6_col6 {
#   background-color: #298abd;
#   color: #f1f1f1;
# }
# #T_415cb_row6_col7 {
#   background-color: #7accc4;
#   color: #000000;
# }
# #T_415cb_row6_col8, #T_415cb_row6_col9, #T_415cb_row6_col13, #T_415cb_row6_col15 {
#   background-color: #76c9c6;
#   color: #000000;
# }
# #T_415cb_row6_col16 {
#   background-color: #bbe4bd;
#   color: #000000;
# }
# #T_415cb_row7_col6 {
#   background-color: #1677b3;
#   color: #f1f1f1;
# }
# #T_415cb_row7_col16 {
#   background-color: #3699c5;
#   color: #f1f1f1;
# }
# #T_415cb_row8_col6 {
#   background-color: #bfe6bf;
#   color: #000000;
# }
# #T_415cb_row8_col16 {
#   background-color: #64bfcc;
#   color: #000000;
# }
# #T_415cb_row9_col6 {
#   background-color: #67c1cb;
#   color: #000000;
# }
# #T_415cb_row9_col7 {
#   background-color: #e0f3db;
#   color: #000000;
# }
# #T_415cb_row9_col8, #T_415cb_row9_col9, #T_415cb_row9_col13, #T_415cb_row9_col15 {
#   background-color: #def2d9;
#   color: #000000;
# }
# #T_415cb_row9_col16 {
#   background-color: #b6e3bb;
#   color: #000000;
# }
# </style>
# <table id="T_415cb_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Invoice ID</th>
#       <th class="col_heading level0 col1" >Branch</th>
#       <th class="col_heading level0 col2" >City</th>
#       <th class="col_heading level0 col3" >Customer type</th>
#       <th class="col_heading level0 col4" >Gender</th>
#       <th class="col_heading level0 col5" >Product line</th>
#       <th class="col_heading level0 col6" >Unit price</th>
#       <th class="col_heading level0 col7" >Quantity</th>
#       <th class="col_heading level0 col8" >Tax 5%</th>
#       <th class="col_heading level0 col9" >Total</th>
#       <th class="col_heading level0 col10" >Date</th>
#       <th class="col_heading level0 col11" >Time</th>
#       <th class="col_heading level0 col12" >Payment</th>
#       <th class="col_heading level0 col13" >cogs</th>
#       <th class="col_heading level0 col14" >gross margin percentage</th>
#       <th class="col_heading level0 col15" >gross income</th>
#       <th class="col_heading level0 col16" >Rating</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_415cb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_415cb_row0_col0" class="data row0 col0" >750-67-8428</td>
#       <td id="T_415cb_row0_col1" class="data row0 col1" >A</td>
#       <td id="T_415cb_row0_col2" class="data row0 col2" >Yangon</td>
#       <td id="T_415cb_row0_col3" class="data row0 col3" >Member</td>
#       <td id="T_415cb_row0_col4" class="data row0 col4" >Female</td>
#       <td id="T_415cb_row0_col5" class="data row0 col5" >Health and beauty</td>
#       <td id="T_415cb_row0_col6" class="data row0 col6" >74.690000</td>
#       <td id="T_415cb_row0_col7" class="data row0 col7" >7</td>
#       <td id="T_415cb_row0_col8" class="data row0 col8" >26.141500</td>
#       <td id="T_415cb_row0_col9" class="data row0 col9" >548.971500</td>
#       <td id="T_415cb_row0_col10" class="data row0 col10" >1/5/2019</td>
#       <td id="T_415cb_row0_col11" class="data row0 col11" >13:08</td>
#       <td id="T_415cb_row0_col12" class="data row0 col12" >Ewallet</td>
#       <td id="T_415cb_row0_col13" class="data row0 col13" >522.830000</td>
#       <td id="T_415cb_row0_col14" class="data row0 col14" >4.761905</td>
#       <td id="T_415cb_row0_col15" class="data row0 col15" >26.141500</td>
#       <td id="T_415cb_row0_col16" class="data row0 col16" >9.100000</td>
#     </tr>
#     <tr>
#       <th id="T_415cb_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_415cb_row1_col0" class="data row1 col0" >226-31-3081</td>
#       <td id="T_415cb_row1_col1" class="data row1 col1" >C</td>
#       <td id="T_415cb_row1_col2" class="data row1 col2" >Naypyitaw</td>
#       <td id="T_415cb_row1_col3" class="data row1 col3" >Normal</td>
#       <td id="T_415cb_row1_col4" class="data row1 col4" >Female</td>
#       <td id="T_415cb_row1_col5" class="data row1 col5" >Electronic accessories</td>
#       <td id="T_415cb_row1_col6" class="data row1 col6" >15.280000</td>
#       <td id="T_415cb_row1_col7" class="data row1 col7" >5</td>
#       <td id="T_415cb_row1_col8" class="data row1 col8" >3.820000</td>
#       <td id="T_415cb_row1_col9" class="data row1 col9" >80.220000</td>
#       <td id="T_415cb_row1_col10" class="data row1 col10" >3/8/2019</td>
#       <td id="T_415cb_row1_col11" class="data row1 col11" >10:29</td>
#       <td id="T_415cb_row1_col12" class="data row1 col12" >Cash</td>
#       <td id="T_415cb_row1_col13" class="data row1 col13" >76.400000</td>
#       <td id="T_415cb_row1_col14" class="data row1 col14" >4.761905</td>
#       <td id="T_415cb_row1_col15" class="data row1 col15" >3.820000</td>
#       <td id="T_415cb_row1_col16" class="data row1 col16" >9.600000</td>
#     </tr>
#     <tr>
#       <th id="T_415cb_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_415cb_row2_col0" class="data row2 col0" >631-41-3108</td>
#       <td id="T_415cb_row2_col1" class="data row2 col1" >A</td>
#       <td id="T_415cb_row2_col2" class="data row2 col2" >Yangon</td>
#       <td id="T_415cb_row2_col3" class="data row2 col3" >Normal</td>
#       <td id="T_415cb_row2_col4" class="data row2 col4" >Male</td>
#       <td id="T_415cb_row2_col5" class="data row2 col5" >Home and lifestyle</td>
#       <td id="T_415cb_row2_col6" class="data row2 col6" >46.330000</td>
#       <td id="T_415cb_row2_col7" class="data row2 col7" >7</td>
#       <td id="T_415cb_row2_col8" class="data row2 col8" >16.215500</td>
#       <td id="T_415cb_row2_col9" class="data row2 col9" >340.525500</td>
#       <td id="T_415cb_row2_col10" class="data row2 col10" >3/3/2019</td>
#       <td id="T_415cb_row2_col11" class="data row2 col11" >13:23</td>
#       <td id="T_415cb_row2_col12" class="data row2 col12" >Credit card</td>
#       <td id="T_415cb_row2_col13" class="data row2 c

# %%
shape=supermarket_df.shape
print(f'The dataset contains {shape[0]} rows and {shape[1]} columns')
# Out:
# The dataset contains 1000 rows and 17 columns

# %%
# Display the number of parameters
supermarket_df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %% [markdown]
# <h3 style="color: #B0E0E6; background-color: #7C99BD;">
#     DATA PREPROCESSING
# <br>
# </h3>

# %%
#Chech the Nan values
supermarket_df.isna().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
#Visualize the nan values in each columns
msno.matrix(supermarket_df);

# %%
#Check the dype of each columns
supermarket_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
#  14  gross margin percentage  1000 non-null   float64
#  15  gross income             1000 non-null   float64
#  16  Rating                   1000 non-null   float64
# dtypes: float64(7), int64(1), object(9)
# memory usage: 132.9+ KB

# %% [markdown]
# #### Let's convert the date and time columns into date/time dtypes

# %%
# modified_df=supermarket_df.copy()

# Convert date columns into date time 
supermarket_df.Date = pd.to_datetime(supermarket_df.Date)
#Add a month,day and weekday columns
supermarket_df['month']=supermarket_df.Date.dt.month
supermarket_df['day']=supermarket_df.Date.dt.day
supermarket_df['weekday']=supermarket_df.Date.dt.day_name()
#Add a hour and minute columns 
supermarket_df['hour']=supermarket_df.Time.str[0:2]
supermarket_df['minute']=supermarket_df.Time.str[3:5]
#Make it int values
supermarket_df['hour']=pd.to_numeric(supermarket_df['hour'])
supermarket_df['minute']=pd.to_numeric(supermarket_df['minute'])

# %%
supermarket_df.dtypes
# Out:
# Invoice ID                         object
# Branch                             object
# City                               object
# Customer type                      object
# Gender                             object
# Product line                       object
# Unit price                        float64
# Quantity                            int64
# Tax 5%                            float64
# Total                             float64
# Date                       datetime64[ns]
# Time                               object
# Payment                            object
# cogs                              float64
# gross margin percentage           float64
# gross income                      float64
# Rating                            float64
# month                               int64
# day                                 int64
# weekday                            object
# hour                                int64
# minute                              int64
# dtype: object

# %%
supermarket_df.describe().style.background_gradient(cmap='BuPu')
# Out:
# <style type="text/css">
# #T_89f9e_row0_col0, #T_89f9e_row0_col1, #T_89f9e_row0_col2, #T_89f9e_row0_col4, #T_89f9e_row0_col5, #T_89f9e_row0_col6, #T_89f9e_row0_col7, #T_89f9e_row0_col8, #T_89f9e_row0_col9, #T_89f9e_row0_col10, #T_89f9e_row0_col11, #T_89f9e_row7_col3 {
#   background-color: #4d004b;
#   color: #f1f1f1;
# }
# #T_89f9e_row0_col3 {
#   background-color: #5d055a;
#   color: #f1f1f1;
# }
# #T_89f9e_row1_col0, #T_89f9e_row5_col0, #T_89f9e_row6_col11 {
#   background-color: #eff6fa;
#   color: #000000;
# }
# #T_89f9e_row1_col1, #T_89f9e_row1_col5, #T_89f9e_row1_col7, #T_89f9e_row2_col9, #T_89f9e_row3_col5, #T_89f9e_row3_col10, #T_89f9e_row4_col2, #T_89f9e_row4_col5, #T_89f9e_row4_col6, #T_89f9e_row4_col9, #T_89f9e_row5_col1, #T_89f9e_row5_col5, #T_89f9e_row5_col7, #T_89f9e_row6_col1, #T_89f9e_row6_col5, #T_89f9e_row6_col7, #T_89f9e_row7_col5 {
#   background-color: #f6fbfd;
#   color: #000000;
# }
# #T_89f9e_row1_col2, #T_89f9e_row1_col6, #T_89f9e_row1_col9, #T_89f9e_row1_col10, #T_89f9e_row5_col9, #T_89f9e_row5_col10, #T_89f9e_row6_col10 {
#   background-color: #f5fafc;
#   color: #000000;
# }
# #T_89f9e_row1_col3 {
#   background-color: #b1c9e1;
#   color: #000000;
# }
# #T_89f9e_row1_col4 {
#   background-color: #b2cae1;
#   color: #000000;
# }
# #T_89f9e_row1_col8, #T_89f9e_row2_col1, #T_89f9e_row2_col5, #T_89f9e_row2_col7, #T_89f9e_row2_col8, #T_89f9e_row2_col10, #T_89f9e_row3_col0, #T_89f9e_row3_col1, #T_89f9e_row3_col2, #T_89f9e_row3_col3, #T_89f9e_row3_col4, #T_89f9e_row3_col6, #T_89f9e_row3_col7, #T_89f9e_row3_col8, #T_89f9e_row3_col9, #T_89f9e_row3_col11, #T_89f9e_row4_col1, #T_89f9e_row4_col7, #T_89f9e_row4_col8, #T_89f9e_row5_col8, #T_89f9e_row6_col8, #T_89f9e_row7_col8 {
#   background-color: #f7fcfd;
#   color: #000000;
# }
# #T_89f9e_row1_col11, #T_89f9e_row5_col11, #T_89f9e_row7_col9 {
#   background-color: #f2f8fb;
#   color: #000000;
# }
# #T_89f9e_row2_col0, #T_89f9e_row2_col11, #T_89f9e_row4_col11, #T_89f9e_row7_col10 {
#   background-color: #f4fafc;
#   color: #000000;
# }
# #T_89f9e_row2_col2, #T_89f9e_row2_col6, #T_89f9e_row4_col10, #T_89f9e_row5_col2, #T_89f9e_row5_col6, #T_89f9e_row7_col1, #T_89f9e_row7_col7 {
#   background-color: #f6fbfc;
#   color: #000000;
# }
# #T_89f9e_row2_col3 {
#   background-color: #c5d8e9;
#   color: #000000;
# }
# #T_89f9e_row2_col4 {
#   background-color: #c6d8e9;
#   color: #000000;
# }
# #T_89f9e_row4_col0, #T_89f9e_row6_col2, #T_89f9e_row6_col6, #T_89f9e_row6_col9 {
#   background-color: #f3f9fc;
#   color: #000000;
# }
# #T_89f9e_row4_col3, #T_89f9e_row4_col4 {
#   background-color: #e3eef5;
#   color: #000000;
# }
# #T_89f9e_row5_col3 {
#   background-color: #c3d6e8;
#   color: #000000;
# }
# #T_89f9e_row5_col4 {
#   background-color: #c4d7e8;
#   color: #000000;
# }
# #T_89f9e_row6_col0 {
#   background-color: #ebf3f8;
#   color: #000000;
# }
# #T_89f9e_row6_col3 {
#   background-color: #94a6ce;
#   color: #f1f1f1;
# }
# #T_89f9e_row6_col4 {
#   background-color: #94a7cf;
#   color: #f1f1f1;
# }
# #T_89f9e_row7_col0 {
#   background-color: #e6f0f7;
#   color: #000000;
# }
# #T_89f9e_row7_col2, #T_89f9e_row7_col6 {
#   background-color: #eef6fa;
#   color: #000000;
# }
# #T_89f9e_row7_col4 {
#   background-color: #4f004d;
#   color: #f1f1f1;
# }
# #T_89f9e_row7_col11 {
#   background-color: #ecf4f9;
#   color: #000000;
# }
# </style>
# <table id="T_89f9e_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Unit price</th>
#       <th class="col_heading level0 col1" >Quantity</th>
#       <th class="col_heading level0 col2" >Tax 5%</th>
#       <th class="col_heading level0 col3" >Total</th>
#       <th class="col_heading level0 col4" >cogs</th>
#       <th class="col_heading level0 col5" >gross margin percentage</th>
#       <th class="col_heading level0 col6" >gross income</th>
#       <th class="col_heading level0 col7" >Rating</th>
#       <th class="col_heading level0 col8" >month</th>
#       <th class="col_heading level0 col9" >day</th>
#       <th class="col_heading level0 col10" >hour</th>
#       <th class="col_heading level0 col11" >minute</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_89f9e_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_89f9e_row0_col0" class="data row0 col0" >1000.000000</td>
#       <td id="T_89f9e_row0_col1" class="data row0 col1" >1000.000000</td>
#       <td id="T_89f9e_row0_col2" class="data row0 col2" >1000.000000</td>
#       <td id="T_89f9e_row0_col3" class="data row0 col3" >1000.000000</td>
#       <td id="T_89f9e_row0_col4" class="data row0 col4" >1000.000000</td>
#       <td id="T_89f9e_row0_col5" class="data row0 col5" >1000.000000</td>
#       <td id="T_89f9e_row0_col6" class="data row0 col6" >1000.000000</td>
#       <td id="T_89f9e_row0_col7" class="data row0 col7" >1000.000000</td>
#       <td id="T_89f9e_row0_col8" class="data row0 col8" >1000.000000</td>
#       <td id="T_89f9e_row0_col9" class="data row0 col9" >1000.000000</td>
#       <td id="T_89f9e_row0_col10" class="data row0 col10" >1000.000000</td>
#       <td id="T_89f9e_row0_col11" class="data row0 col11" >1000.000000</td>
#     </tr>
#     <tr>
#       <th id="T_89f9e_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_89f9e_row1_col0" class="data row1 col0" >55.672130</td>
#       <td id="T_89f9e_row1_col1" class="data row1 col1" >5.510000</td>
#       <td id="T_89f9e_row1_col2" class="data row1 col2" >15.379369</td>
#       <td id="T_89f9e_row1_col3" class="data row1 col3" >322.966749</td>
#       <td id="T_89f9e_row1_col4" class="data row1 col4" >307.587380</td>
#       <td id="T_89f9e_row1_col5" class="data row1 col5" >4.761905</td>
#       <td id="T_89f9e_row1_col6" class="data row1 col6" >15.379369</td>
#       <td id="T_89f9e_row1_col7" class="data row1 col7" >6.972700</td>
#       <td id="T_89f9e_row1_col8" class="data row1 col8" >1.993000</td>
#       <td id="T_89f9e_row1_col9" class="data row1 col9" >15.256000</td>
#       <td id="T_89f9e_row1_col10" class="data row1 col10" >14.910000</td>
#       <td id="T_89f9e_row1_col11" class="data row1 col11" >30.098000</td>
#     </tr>
#     <tr>
#       <th id="T_89f9e_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_89f9e_row2_col0" class="data row2 col0" >26.494628</td>
#       <td id="T_89f9e_row2_col1" class="data row2 col1" >2.923431</td>
#       <td id="T_89f9e_row2_col2" class="data row2 col2" >11.708825</td>
#       <td id="T_89f9e_row2_col3" class="data row2 col3" >245.885335</td>
#       <td id="T_89f9e_row2_col4" class="data row2 col4" >234.176510</td>
#       <td id="T_89f9e_row2_col5" class="data row2 col5" >0.000000</td>
#       <td id="T_89f9e_row2_col6" class="data row2 col6" >11.708825</td>
#       <td id="T_89f9e_row2_col7" class="data row2 col7" >1.718580</td>
#       <td id="T_89f9e_row2_col8" class="data row2 col8" >0.835254</td>
#       <td id="T_89f9e_row2_col9" class="data row2 col9" >8.693563</td>
#       <td id="T_89f9e_row2_col10" class="data row2 col10" >3.186857</td>
#       <td id="T_89f9e_row2_col11" class="data row2 col11" >16.880680</td>
#     </tr>
#     <tr>
#       <th id="T_89f9e_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_89f9e_row3_col0" class="data row3 col0" >10.080000</td>
#       <td id="T_89f9e_row3_col1" class="data row3 col1" >1.000000</td>
#       <td id="T_89f9e_row3_col2" class="data row3 col2" >0.508500</td>
#       <td id="T_89f9e_row3_col3" class="data row3 col3" >10.678500</td>
#       <td id="T_89f9e_row3_col4" class="data row3 col4" >10.170000</td>
#       <td id="T_89f9e_row3_col5" class="data row3 col5" >4.761905</td>
#       <td id="T_89f9e_row3_col6" class="data row3 col6" >0.508500</td>
#       <td id="T_89f9e_row3_col7" class="data row3 col7" >4.000000</td>
#       <td id="T_89f9e_row3_col8" class="data row3 col8" >1.000000</td>
#       <td id="T_89f9e_row3_col9" class="data row3 col9" >1.000000</td>
#       <td id="T_89f9e_row3_col10" class="data row3 col10" >10.000000</td>
#       <td id="T_89f9e_row3_col11" class="data row3 col11" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_89f9e_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_89f9e_row4_col0" class="data row4 col0" >32.875000</td>

# %% [markdown]
# <h3 style="color: #B0E0E6; background-color: #7C99BD;">
#     EXPLORATORY ANALYSIS
# <br>
# </h3>

# %%
# supermarket_df

# %%
#Matplotlib config
sns.set_style('darkgrid')

matplotlib.rcParams['font.size'] = 14
matplotlib.rcParams['figure.figsize'] = (12,9)
matplotlib.rcParams['figure.facecolor'] = '#00000000'

# %% [markdown]
# ## CITY

# %%
supermarket_df.City.unique()
# Out:
# array(['Yangon', 'Naypyitaw', 'Mandalay'], dtype=object)

# %%
cities = pd.DataFrame({'city': ['Yangon', 'Naypyitaw', 'Mandalay'],
                       'Latitude': [16.8409,19.7633,21.9588],
                       'Longitude' : [96.1735, 96.0785, 96.0891]})

market_map = folium.Map(location = [21.9162,95.9560], zoom_start = 5, tiles = 'CartoDB Positron', control_scale = True)

plt.figure(figsize=(800,600));

for (i, j) in cities.iterrows():
  folium.Marker(location = [j.loc['Latitude'], j.loc['Longitude']], popup = j.loc['city'],tooltip = 'click',
                icon = folium.Icon(icon = 'glyphicon-shopping-cart', prefix = 'glyphicon')).add_to(market_map)

market_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_04de005efefd42fca2650f2df5f73adf%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_04de005efefd42fca2650f2df5f73adf%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_04de005efefd42fca2650f2df5f73adf%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_04de005efefd42fca2650f2df5f73adf%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B21.9162%2C%2095.956%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %%
# supermarket_df.groupby('City').count()
plt.title('Amount of Transaction per City')
sns.barplot(x='City',y='Total',data=supermarket_df,hue='Branch');

# %%
#Parameter for plotting 
sale=supermarket_df.groupby('City').sum()['Total'] #Y-values
cities=[city for city, supermarket_df in supermarket_df.groupby('City')] #X-values

# Plot
plt.bar(cities,sale,color='orange',alpha=.6)
plt.xlabel('Cities')
plt.ylabel('Sales')
plt.title('Highest Sale per city')
plt.show()

# %% [markdown]
# Observation: Naypitaw has the highest sale however Mandalay and Yangon are not too far from Naypitaw.

# %% [markdown]
# ## Month

# %%
#Parameters for plotting 
sale=supermarket_df.groupby('month').sum()['Total']
month=['January','February','March']
c=['b','k','b']
#Plot
plt.figure(figsize=(12,9))
plt.bar(month,sale,color=c)
plt.title('Number of Sales per Month')
plt.show()
# print(sale)

# %% [markdown]
# Observations: The supermarket performs well in January. It has a decrease in transaction in February and bounces back in March

# %% [markdown]
# ## Quantity

# %%
#Y-axis
quantity=supermarket_df.groupby('month').sum()['Quantity']

#Plot
plt.title('Quantity of product by Month')
plt.bar(month,quantity,color=c)
plt.show()

# %% [markdown]
# Observations: The quantity graph follows a similar pattern to the Sale graph. We have a correlation between the number of products and the number of items sold.

# %%
#Plot an histogram
plt.title('Distribution of Products')
sns.histplot(supermarket_df.Quantity,alpha=0.5, bins=10);

# %% [markdown]
# Observation: The Quantity of product is well distributed across

# %% [markdown]
# ## Payment

# %%
# Parameters for plotting
method=supermarket_df.groupby('Payment').count()['Total']
payment=['Cash','Credit card','Ewallet']
c=['k','b','r']
# Plot 
plt.figure(figsize=(12,6))
plt.bar(payment,method,color=c,alpha=0.8)
plt.xlabel('Type of Payment')
plt.ylabel('Count')
plt.title('Method of Payment')
plt.show()

# %% [markdown]
# Observation: Cash is the most used form of payment across each transaction

# %% [markdown]
# ## Rating

# %%
plt.title('Rating Distribution by Branch')
sns.violinplot('Branch','Rating',data=supermarket_df);
# Out:
# D:\anaconda3\envs\data\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# Observation:
#
# Branch A has received the most positive rating due to the tapered shape toward the middle between the values 6 to 9.
# Branch B has the most negative rating due to the tapered shape between the values 4 to 6.
# Branch C has an almost equal positive and negative ratings between the value 4 to 6 and 8 to 10

# %%
# (supermarket_df['Rating'][supermarket_df['Branch']=='B'].sum()/6972.69)*100
# (supermarket_df['Rating'][supermarket_df['Branch']=='A'].sum()/6972.69)*100
# (supermarket_df['Rating'][supermarket_df['Branch']=='C'].sum()/6972.69)*100

# %%
# BranchA=supermarket_df[supermarket_df.Branch == 'A']
# BranchB=supermarket_df[supermarket_df.Branch == 'B']
# BranchC=supermarket_df[supermarket_df.Branch == 'C']

# %%
plt.figure(figsize=(12,6))
plt.title('Customer Transaction per Hour')
sns.lineplot(data=supermarket_df,x='hour',y='Total',hue='Customer type',markers=True,style='Customer type',dashes=False);

# %% [markdown]
# Observation: The Normal customers and the members like to shop around noon but members have the highest number of transactions at 2 pm.  Around 4 pm and 9 pm, the normal customers shop the most.

# %%
plt.style.use(['dark_background'])
sns.pairplot(supermarket_df);

# %% [markdown]
# ## Correlation

# %%
#Create a correlation matrix
corr_df=supermarket_df.corr()
#Plot 
plt.figure(figsize=(20,15))
plt.title('Correlation Matrix')
sns.heatmap(corr_df,annot=True)
plt.show()

# %% [markdown]
# Observation:
#
# -The black bars represent the null values (gross margin percentage vs gross margin percentage)
# -The purple represents almost no correlation between the columns
#
# -The orange block represents a high correlation between values. So taxes, Total, and cogs are highly correlated to quantity and unit price
# -The pale block represents the perfect correlation between values of the same columns.

# %% [markdown]
# <h3 style="color: #B0E0E6; background-color: #7C99BD;">
#     QUESTIONS
# <br>
# </h3>
#
#    - What was the total number of sales? What branch has the highest number of sales?
#     What type of product is sold the most?
#
#    - What gender buy the most product? What gender buy more items in each category? what is the category?
#
#    - How many people buy more than the average price in each category? Are they a member of the supermarket?
#
#    - How many female members buy more than the average price in Food and beverages category?
#
#    - What is the favorite method of payment of the members? of the normal customers?
#
#    - What time should we display an advertisement to maximize the revenue?

# %% [markdown]
# **Q1: What was the total number of sales? What branch has the highest number of sales?**

# %%
total_sale=supermarket_df['Total'].sum()
print('The total number of sales of the supermarket is {:.2f}$'.format(total_sale))
# Out:
# The total number of sales of the supermarket is 322966.75$

# %%
sale_branch=supermarket_df.groupby('Branch').sum()['Total']
print('Branch C has the highest number of sale of {}$'.format(max(sale_branch)))
# Out:
# Branch C has the highest number of sale of 110568.7065$

# %%
#Plot style
plt.style.use('default')
sns.set_style('darkgrid')

#Paramter for the x-axis
branches = [branch for branch, supermarket_df in supermarket_df.groupby('Branch')]
#Plot the graph

plt.bar(branches,sale_branch,alpha=0.5,color='g')
plt.xlabel('Branches')
plt.ylabel('Sales')
plt.legend(['sale'])
plt.show()

# %% [markdown]
# **Q2:What type of product is sold the most?**

# %%
#Parameters
sale_product=supermarket_df.groupby('Product line').sum()['Total']
products =[product for product, supermarket_df in supermarket_df.groupby('Product line')]
c=['r','r','k','r','r','r']
#Plot the graph
plt.figure(figsize=(12,6))
plt.bar(products,sale_product,alpha=0.6,color=c)
plt.xticks(products, rotation='vertical')
plt.xlabel('Products')
plt.ylabel('Sales')
plt.legend(['sale'],loc='upper left')
plt.show()

# %% [markdown]
# **Q3:What gender buy the most product? What gender buy more items in each category? what is the category?**

# %%
#Plot Gender purchase by product line
plt.figure(figsize=(12,10))
plt.title('Gender Purchase')
sns.scatterplot(x='Product line',y='Total',hue='Gender',data=supermarket_df);

# %%
gender_market=supermarket_df[['Gender','Total','Product line','Customer type']].sort_values('Total',ascending=False)

# %%
gender_market['male']=gender_market['Gender'][gender_market['Gender'] == 'Male']
gender_market['female']=gender_market['Gender'][gender_market.Gender.str.contains('Female')]
product_gender=gender_market.groupby('Product line').count()
product_gender
# male=product_gender['male']/product_gender['Total'].tolist()
gender_market.drop(columns=['male','female'],inplace=True)

# %%
print('Men buy more product in 3 categories: \nElectronic accessories: 86 men\nHealth and beauty: 88 men\nHome and lifestyle: 81 men\n')
print('Women buy more product in 3 categories: \nFashion accessories: 96 women\nFood and beverages: 90 women\nsports and travel: 88 women ')
# Out:
# Men buy more product in 3 categories:
# Electronic accessories: 86 men
# Health and beauty: 88 men
# Home and lifestyle: 81 men
#
# Women buy more product in 3 categories:
# Fashion accessories: 96 women
# Food and beverages: 90 women
# sports and travel: 88 women

# %% [markdown]
# **Q4: How many people buy more than the average price in each category? Are they a member of the supermarket?**

# %%
mean_sale=gender_market['Total'].mean()
product_line=gender_market['Product line'].unique()
print('The average sale of product is {:.3f}$'.format(mean_sale))
# Out:
# The average sale of product is 322.967$

# %%
people=[]
for product in product_line:
    p=gender_market[(gender_market['Total']>322.96) & (gender_market['Product line'] == product)].count()['Total']
    people.append(p)
num_people=np.sum(people)

# %%
#Result
print('The number of people who buy more average price by product line are:\n')
for pro, p in zip(product_line,people):
    print(f'{pro}: {p} people')
print(f'\nFor a total of {num_people} people')
# Out:
# The number of people who buy more average price by product line are:
#
# Fashion accessories: 69 people
# Food and beverages: 67 people
# Home and lifestyle: 66 people
# Sports and travel: 75 people
# Health and beauty: 60 people
# Electronic accessories: 67 people
#
# For a total of 404 people

# %%
plt.figure(figsize=(12,9))
plt.title('Customer Purchase')
sns.scatterplot(x='Product line',y='Total',hue='Customer type',data=supermarket_df);

# %%
member=gender_market[(gender_market['Total']>322.96) & (gender_market['Customer type'] == 'Member')].count()['Total']
member_percentage =(member/num_people)*100
print('{:.2f}% that buy more than the average price are members'.format(member_percentage))
# Out:
# 50.50% that buy more than the average price are members

# %% [markdown]
# **Q5: How many female members buy more than the average price in `Food and beverages` category?**

# %%
gender_market[(gender_market['Total']>322.96) & (gender_market['Gender'] == 'Female') & (gender_market['Product line'] == 'Food and beverages') & (gender_market['Customer type'] == 'Member')].count()['Total']
# Out:
# 23

# %% [markdown]
# **Q6: What is the favorite method of payment of the members? of the normal customers?**

# %%
# supermarket_df

# %%
member_df=supermarket_df[supermarket_df['Customer type']=='Member']
Ncustomer_df=supermarket_df[supermarket_df['Customer type']=='Normal']

# %%
print('Cash is used the most as method of payment')
# Out:
# Cash is used the most as method of payment

# %%
#Parameters for plotting
method=member_df.groupby('Payment').count()['Customer type']
payment=['Cash','Credit card','Ewallet']
c=['k','b','r']
#Plot the bar figure 

plt.pie(method,colors=c,labels=payment,explode=[0,0.03,0],autopct='%1.1f%%')
plt.title('Favorite Method of Payment for Members')
plt.show()

# %%
print('The favorite method of payment for the member is credit card and cash')
# Out:
# The favorite method of payment for the member is credit card and cash

# %%
#Parameters for plotting
method=Ncustomer_df.groupby('Payment').count()['Customer type']
payment=['Cash','Credit card','Ewallet']
c=['k','b','r']
#Plot 
plt.pie(method,colors=c,labels=payment,startangle=60,explode=[0,0,0.03],autopct='%1.1f%%')
plt.title('Favorite Method of Payment for Normal Clients')
plt.show()

# %%
print('The favorite method of payment for the member is Ewallet following by Cash')
# Out:
# The favorite method of payment for the member is Ewallet following by Cash

# %% [markdown]
# **Q7: What time should we display an advertisement to maximize the revenue?**

# %%
#Parameter for plotting
sale=supermarket_df.groupby('hour').sum()['Total']
hours=[hour for hour, supermarket_df in supermarket_df.groupby('hour')]

# %%
#Plot
plt.plot(hours,sale,'o--r')
plt.xlabel('Hour')
plt.xticks(hours)
plt.ylabel('Sales')
plt.title('Best Time to Display Advertisement')
plt.legend(['time'])
plt.show()

# %%
print('We should display advertisement to the customer before 13h and 19h')
# supermarket_df.groupby('hour').sum()['Total']
# Out:
# We should display advertisement to the customer before 13h and 19h

# %% [markdown]
# <h3 style="color: #B0E0E6; background-color: #7C99BD;">
#     INFERENCES AND CONCLUSION
# <br>
# </h3>
#
# We have drawn many inferences from the dataframe. Here is a summary of a few of them:
# * Branch C that is in `Naypyitaw` has the highest number of transaction and sales
# * February has the lowest number of sales and January account for the most sales
# * The quantity of product is well distributed across the bord
# * Food and beverage category produces the most amount of sale
# * Men purchase more products in 3 categories : `Electronics`, `health and beauty`, `home and lifestyle`.
# * Women purchase more products in 3 categories: `Fashion`, `Food and beverages`, and `travel`
# * 404 people out 1000 buy more the average price. Sport and travel category has the most `(75)people` who buy more than the average price
# * `Cash` is the favorite method of payment accross costumers. The member used a credit card and cash to complete transaction. The normal costumer prefer to use Ewallet and cash
# * The favorite time to display advertisement is before 13h and 19h

# %% [markdown]
# <h3 style="color: #B0E0E6; background-color: #7C99BD;">
#     REFERENCES AND FUTURE WORK
# <br>
# </h3>
#
# - `Zerotopandas` : https://jovian.ml/aakashns/zerotopandas-course-project-starter
# - `opendatasets` Python library: https://github.com/JovianML/opendatasets
#
# As a next step, I could explore a recommandation algorithm based on the customer type
